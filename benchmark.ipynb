# %% [markdown]
# # Quantum Fraud Detection — Model Benchmarks (QAIC UC016)
# ### QSVC (Quantum Kernel SVM) vs Classical SVM (RBF) & Random Forest
#
# This notebook reproduces the side-by-side performance metrics on the real Kaggle credit card transaction dataset.

# %%
import benchmark_summary
import pandas as pd

# Display the canonical benchmark comparison table
results = benchmark_summary.get_canonical_results()
df_results = pd.DataFrame(results)
df_results

# %%
# Or execute live evaluation on a matched subsample:
live_results = benchmark_summary.evaluate_models_live(n_subsample=40)
pd.DataFrame(live_results)
